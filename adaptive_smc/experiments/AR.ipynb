# %%
import pickle
import os
import matplotlib.pyplot as plt
import numpy as np
import jax.numpy as jnp
import pandas as pd

PKLs = []
PKL_titles = []
for file in os.listdir("./"):
    if file.endswith(".pkl"):
        PKLs.append(pickle.load(open(file, "rb")))
        PKL_titles.append(str(file))
n = len(PKLs)

# %%
list_idx_rwmh = []
list_idx_ar = []
for i in range(n):
    if 'gamma' in PKLs[i]['config']['proposal']:
        list_idx_rwmh.append(i)
    else:
        list_idx_ar.append(i)
for idx in list_idx_ar:
    plt.plot(np.mean(PKLs[idx]['res'][3], axis=0), label=f'tau: {str(PKLs[idx]['config']['tau'])[:4]}')
plt.ylabel("Acceptance-Ratio")
plt.xlabel("iteration")
plt.legend()
# Out:
# /tmp/ipykernel_16514/3712554084.py:12: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
